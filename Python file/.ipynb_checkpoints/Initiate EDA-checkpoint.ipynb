# %%
import os
import pandas as pd
import numpy as np
import copy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


train = pd.read_csv('train.csv',encoding = 'big5')
test = pd.read_csv('test.csv',encoding = 'big5')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (17,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_y = train['Y1']
train_num = train_y.shape[0]
# train_num

labelencoder = LabelEncoder()
train_y = labelencoder.fit_transform(train_y)
train_y
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
num_features = [ ]
for dtype, feature in zip(train.dtypes, train.columns):
    if dtype == 'float64' or dtype == 'int64':
        num_features.append(feature)
print(f'{len(num_features)} Numeric Features : {num_features}\n')
# Out:
# 42 Numeric Features : ['CUS_ID', 'EDUCATION_CD', 'MARRIAGE_CD', 'L1YR_A_ISSUE_CNT', 'L1YR_B_ISSUE_CNT', 'CHANNEL_A_POL_CNT', 'CHANNEL_B_POL_CNT', 'OCCUPATION_CLASS_CD', 'APC_CNT', 'INSD_CNT', 'APC_1ST_YEARDIF', 'LEVEL', 'RFM_M_LEVEL', 'ANNUAL_PREMIUM_AMT', 'AG_CNT', 'AG_NOW_CNT', 'CLC_CUR_NUM', 'ANNUAL_INCOME_AMT', 'L1YR_C_CNT', 'BANK_NUMBER_CNT', 'INSD_LAST_YEARDIF_CNT', 'BMI', 'IM_CNT', 'TERMINATION_RATE', 'TOOL_VISIT_1YEAR_CNT', 'DIEBENEFIT_AMT', 'DIEACCIDENT_AMT', 'POLICY_VALUE_AMT', 'ANNUITY_AMT', 'EXPIRATION_AMT', 'ACCIDENT_HOSPITAL_REC_AMT', 'DISEASES_HOSPITAL_REC_AMT', 'OUTPATIENT_SURGERY_AMT', 'INPATIENT_SURGERY_AMT', 'PAY_LIMIT_MED_MISC_AMT', 'FIRST_CANCER_AMT', 'ILL_ACCELERATION_AMT', 'ILL_ADDITIONAL_AMT', 'LONG_TERM_CARE_AMT', 'MONTHLY_CARE_AMT', 'LIFE_INSD_CNT', 'L1YR_GROSS_PRE_AMT']

# %%
train1 = train[num_features]
a = train1.columns[train1.isna().any()].tolist()

# %%
train1 = train[a]
train1.columns
# Out:
# Index(['EDUCATION_CD', 'MARRIAGE_CD', 'OCCUPATION_CLASS_CD', 'APC_1ST_YEARDIF',
#        'LEVEL', 'RFM_M_LEVEL', 'ANNUAL_PREMIUM_AMT', 'ANNUAL_INCOME_AMT',
#        'L1YR_C_CNT', 'INSD_LAST_YEARDIF_CNT', 'BMI', 'TERMINATION_RATE',
#        'DIEBENEFIT_AMT', 'DIEACCIDENT_AMT', 'POLICY_VALUE_AMT', 'ANNUITY_AMT',
#        'EXPIRATION_AMT', 'ACCIDENT_HOSPITAL_REC_AMT',
#        'DISEASES_HOSPITAL_REC_AMT', 'OUTPATIENT_SURGERY_AMT',
#        'INPATIENT_SURGERY_AMT', 'PAY_LIMIT_MED_MISC_AMT', 'FIRST_CANCER_AMT',
#        'ILL_ACCELERATION_AMT', 'ILL_ADDITIONAL_AMT', 'LONG_TERM_CARE_AMT',
#        'MONTHLY_CARE_AMT'],
#       dtype='object')

# %% [markdown]
# ## EDA探索有空值的欄位特質
# ### 補空值
# - EDUCATION_CD (K-MEANS，可能參考年齡、性別)
# - MARRIAGE_CD (可能與男女結婚比例)
# - OCCUPATION_CLASS_CD (客戶職業對投保風險程度,可以按比例填or眾數)
# - L1YR_A_ISSUE_CNT (近一年透過A通路投保的次數,眾數1 佔90%)
# - APC_1ST_YEARDIF (距離首次成為要保人相隔時間, 呈現很詭異的分佈要馬隔很短要馬隔很久，問教授)
# - LEVEL(往來關係等級,雙峰趨勢)
# - APC_1ST_AGE(首次擔任要保人的年齡,呈現季節高峰，可能跟推廣季有關，查time-series)
# - RFM_M_LEVEL(距離上次投保間隔多久)
# - ANNUAL_PREMIUM_AMT(年繳化保費,超偏態分佈，要搜尋一下怎麼填空值)
# - L1YR_C_CNT(近一年內到C通路辦保險的次數，缺太多考慮丟掉)
# - INSD_LAST_YEARDIF_CNT(雖便填個平均值交差了事)

# %%
train1[~train1['EDUCATION_CD'].isnull()]['EDUCATION_CD'].hist(bins = 50)

# %%
# train1[~train1['MARRIAGE_CD'].isnull()]['MARRIAGE_CD'].hist(bins = 50)
sns.countplot(train1['MARRIAGE_CD'], hue=train['GENDER'])

# %%
train1[~train1['OCCUPATION_CLASS_CD'].isnull()]['OCCUPATION_CLASS_CD'].hist(bins = 50)

# %%
train1[~train1['APC_1ST_YEARDIF'].isnull()]['APC_1ST_YEARDIF'].hist(bins = 50)
train1['APC_1ST_YEARDIF'].describe()
# Out:
# count    56718.000000
# mean         0.258769
# std          0.182968
# min          0.000000
# 25%          0.116279
# 50%          0.209302
# 75%          0.418605
# max          0.930233
# Name: APC_1ST_YEARDIF, dtype: float64

# %%
# train[~train['LEVEL'].isnull()]['LEVEL'].hist(bins = 50)
# train1['LEVEL'].fillna(0)
#如何填雙峰
sns.countplot(train1['LEVEL'], hue=train['AGE'])

# %%
train1[~train1['OCCUPATION_CLASS_CD'].isnull()]['OCCUPATION_CLASS_CD'].hist(bins = 50)

# %%
train1[~train1['RFM_M_LEVEL'].isnull()]['RFM_M_LEVEL'].hist(bins = 50)

train['RFM_M_LEVEL'].describe()
# Out:
# count    56718.000000
# mean         5.644910
# std          2.451039
# min          3.000000
# 25%          3.000000
# 50%          5.000000
# 75%          8.000000
# max         10.000000
# Name: RFM_M_LEVEL, dtype: float64

# %%
#Quality correlation matrix

k = 15 #number of variables for heatmap
cols = train1.corr().nlargest(k, 'RFM_M_LEVEL')['RFM_M_LEVEL'].index
cm = train1[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
# train['ANNUAL_PREMIUM_AMT'].describe()
plt.xlim(0,0.02)
train1[~train1['ANNUAL_PREMIUM_AMT'].isnull()]['ANNUAL_PREMIUM_AMT'].hist(bins = 500)

# %%
# train1['ANNUAL_INCOME_AMT'].describe()
print(len(train1[train1['ANNUAL_INCOME_AMT']==0]['ANNUAL_INCOME_AMT'])) #看看是不是很多都為0，結果沒有
plt.xlim(0,0.01)
train1[~train1['ANNUAL_INCOME_AMT'].isnull()]['ANNUAL_INCOME_AMT'].hist(bins = 500)
# Out:
# 10

# %%
train['L1YR_C_CNT'].describe()
#缺太多考慮丟掉
# Out:
# count    12064.000000
# mean         1.994446
# std          2.409648
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         41.000000
# Name: L1YR_C_CNT, dtype: float64

# %%
train1['INSD_LAST_YEARDIF_CNT'].describe()
#雖便填個平均值交差了事
# Out:
# count    99829.000000
# mean         0.172488
# std          0.141153
# min          0.000000
# 25%          0.052632
# 50%          0.157895
# 75%          0.236842
# max          1.000000
# Name: INSD_LAST_YEARDIF_CNT, dtype: float64

# %%
# 有些欄位不顯著(都是0的選了也沒用)
no_redundant = train1.drop(columns=['LONG_TERM_CARE_AMT' , 'MONTHLY_CARE_AMT'],axis = 1)
# Out:
#        EDUCATION_CD  MARRIAGE_CD  OCCUPATION_CLASS_CD  APC_1ST_YEARDIF  LEVEL  \
# 0               NaN          NaN                  1.0         0.046512    3.0
# 1               NaN          NaN                  1.0         0.046512    5.0
# 2               1.0          0.0                  1.0         0.000000    5.0
# 3               NaN          0.0                  1.0         0.162791    5.0
# 4               1.0          0.0                  1.0         0.116279    2.0
# 5               NaN          0.0                  1.0         0.186047    3.0
# 6               NaN          0.0                  1.0         0.069767    3.0
# 7               NaN          0.0                  1.0         0.046512    5.0
# 8               1.0          0.0                  1.0         0.116279    1.0
# 9               NaN          0.0                  1.0         0.139535    1.0
# 10              1.0          0.0                  1.0         0.116279    2.0
# ...

# %% [markdown]
# ## 隨意跑跑回歸

# %%
# train_x = train[a][:train_num]
# train_x 
# estimator = LogisticRegression()
# cross_val_score(estimator, train_x, train_y, cv=5).mean()

# %%
# Base_Model = RandomForestClassifier(random_state=2,n_estimators=250,min_samples_split=20,oob_score=True)
# Base_Model.fit(train_x, train_y)
# print('Base oob score :%.5f' %(Base_Model.oob_score_))
